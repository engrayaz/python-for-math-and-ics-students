# %%
Today, we will extend that knowledge and learn:
How to explore available functions using dir()
Trigonometric functions using the math library
How to select and use functions like sin, cos, tan
import math
Now we can access its functions using dot notation:

# %%
import math

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
#radien
angle=30
rad=math.radians(angle)
print(rad)
# Out:
# 0.5235987755982988

# %%
sinvalue=math.sin(rad)
print(sinvalue)
# Out:
# 0.49999999999999994

# %%
cosvalue=math.cos(rad)
print(cosvalue)
# Out:
# 0.8660254037844387

# %%
angle2=45
rad2=math.radians(angle2)
print(rad2)
# Out:
# 0.7853981633974483

# %%
print(math.tan(rad2))
# Out:
# 0.9999999999999999

# %%
# Summary

Today we learned:
How to explore the math library using dir()

How to convert degrees into radians
How to use trigonometric functions: sin, cos, tan

# %%
# Home work
Write a Python program that performs the following tasks:
Accept an angle in degrees from the user.
Convert the given angle into radians using the Python function.
Using the converted radian value, calculate:
a) Sine of the angle
b) Cosine of the angle
c) Tangent of the angle
