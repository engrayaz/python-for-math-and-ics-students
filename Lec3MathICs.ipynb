# %%
Examples of comparison also called relational operators
Operator       	Meaning	      Example	    Result
 >	         greater than	  10 > 5	     True
<	         less than  	  5 < 3	         False
==	        equal to	      10 == 10	     True
!=	        not equal to	  10 != 7	     True
>=	       greater or equal	  50 >= 50	     True
<=	       less or equal	  40 <= 50	     True

# %%
marks=45
print(marks>=50)
# Out:
# False

# %%
speed=72
limit=60
print(speed<=limit)
# Out:
# False

# %%
a=10
b=20
print(a==b)
# Out:
# False

# %%
F1=float(input("enter value of force one:"))
F2=float(input("enter value of force two:"))
print(F1>=F2)
# Out:
# enter value of force one: 20
# enter value of force two: 25
# False

# %%
F11=(input("enter value of force one:"))
print(type(F11))
# Out:
# enter value of force one: 333
# <class 'str'>

# %%
Home work

a = 25
b = 40

print(a > b)
print(a < b)
F1 = 10
F2 = 15

print(F1 == F2)
print(F1 != F2)
age = float(input("Enter your age: "))
print(age >= 18)
marks = 62
print(marks >= 50)
