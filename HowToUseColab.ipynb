# %%
print("My name")
# Out:
# My name

# %%
x=float(input("enter any number to find its square:"))
print("The square of number is :",x**2)
# Out:
# enter any number to find its square:5
# The square of number is : 25.0

# %%
import math
print(math.pow(2,3))
# Out:
# 8.0

# %%
print(math.radians(90))
# Out:
# 1.5707963267948966
