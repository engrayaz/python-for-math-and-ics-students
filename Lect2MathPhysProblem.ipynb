# %%
Example 1: Equation of Motion
s=Vit+1/2 at² 
Example 2: Force
F = m × a

Example 3: Power
P=V×I

# %%
Vi=10
t=5
a=2
S=Vi*t+1/2 *(a* t**2)#t**2
print(S)
# Out:
# 75.0

# %%
a=4
m=3
F=m*a
print(F)
# Out:
# 12

# %%
V=12
I=2
P=V*I
print(P)
# Out:
# 24

# %%
stringinput=input("Enter value of Voltage:")
V=float(stringinput)
I_string=input("Enter Value of Current:")
I=float(I_string)
P=V*I
print(P)
# Out:
# Enter value of Voltage: 12
# Enter Value of Current: 2
# 24.0

# %%
V=float(input("Enter value of Voltage:"))
I=float(input("Enter Value of Current:"))
P=V*I
print(P)
# Out:
# Enter value of Voltage: 12
# Enter Value of Current: 2
# 24.0

# %%
vi = 20
t = 4
a = 2
s = vi*t + (a*t*t)/2#

# %%
# Practice problems
Problem1 
take input values from key board for Vi,t and a and find and print S
S=Vi*t+1/2 *(a* t**2)#t**2
print(S)

Problem2
take input values from key board for a and m and find and print F
F=m*a
print(F)
