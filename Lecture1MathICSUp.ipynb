# %% [markdown]
# # My First Python Program: Finding Roots
#
# ## What is a Quadratic Equation?
# A quadratic equation is:
#
# ax² + bx + c = 0
#
# To solve it, quadfratic
# ormuratic f(
# (−b±√aacb² − 4
# ))/2a
# or split intottinto ​ox₁ = (-b -+ √(b4ac))
#  / 2a
# x2 = (-b -4ac)) √(b² −/2ther , *2two *2xare solut roots ie iayx=xer or 𝑥=𝑥2 -d 2oots 2,3
# x² -4x + 4 = 0, has roots 2
# x² -7x + 10 = 0, has r
#
# 5x² -4x + 4 = 0, home work oots 5,2

# %%
a=1
b=-7
c=10
x1=(-b+(b**2-4*a*c)**0.5)/(2*a)
x2=(-b-(b**2-4*a*c)**0.5)/(2*a)
print(x1)
print(x2)
# Out:
# 5.0
# 2.0

# %%
a=1
b=-7
c=10

# %%
x1=(-b+(b**2 -4*a*c)**0.5)/(2*a)
x2=(-b-(b**2 -4*a*c)**0.5)/(2*a)

# %%
print(x1)
print(x2)
# Out:
# 5.0
# 2.0

# %%
print(45*(x1)**2 + 100*(x1) + 20 )
# Out:
# 0.0

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = int(input("Enter c: "))

# %%
print(int(x1))
print(int(x2))
# Out:
# 3
# 2
