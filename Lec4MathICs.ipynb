# %%
Operator	Meaning	         Simple Idea
and 	both must be True	 All conditions must be correct
or	    at least one True	Any one condition is enough
not	   reverse the result	True becomes False, False becomes True

# %%
m=2
a=5
print(m>0 and a>0)
# Out:
# True

# %%
m=0
a=5
print(m>0 and a>0)
# Out:
# False

# %%
marks=80
Sports_quota=1
print(marks>80 or Sports_quota==1)
# Out:
# True

# %%
F=5
print(not(F==5))
# Out:
# False

# %%
F=5
print(not (F==10))
# Out:
# True

# %%
marks=float(input("enter marks:"))
attendance=float(input("enter attendace:"))
print(marks>=50 and attendance>=75)
# Out:
# enter marks: 85
# enter attendace: 80
# True

# %%
Practice problem
write code in python taking two numbers from user, and prints
true if both are positive otherwise prints false
Hints: use input,float,print,>=
