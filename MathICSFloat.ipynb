# %%
x=input("enter any number:")
print(type(x))
# Out:
# enter any number: 3.5
# <class 'str'>

# %%
x=float(input("enter any number:"))
print(type(x))
# Out:
# enter any number: 3.5
# <class 'float'>
